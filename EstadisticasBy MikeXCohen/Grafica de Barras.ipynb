# %% [markdown]
# # Seccion: Visualizacion de Datos

# %% [markdown]
# ## Grafico de Barras

# %%
# librerias
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
## creamos los datos para el grafico

# Tamanio del los datos
m = 30 # filas
n = 6 # columnas

#generamos los datos
data = np.zeros((m,n))

for i in range(n):
    data[:,i] = 30*np.random.rand(m) * (2*i/(n-1)-1)**2 + (i+1)**2

print(data)
# Out:
# [[25.90870904  6.38747841  9.11420397 16.72168323 34.0382654  49.44620719]
#  [ 3.81931413 10.92271834 10.00336373 16.15951486 30.21247714 59.78506348]
#  [ 1.3019585   9.17812916  9.83091347 16.68855826 30.23916325 50.90763328]
#  [27.78006209  5.28880955  9.26728387 16.47405372 26.90503879 60.13739234]
#  [15.15489646  8.80610833 10.11118807 16.74827093 35.11578204 51.01490311]
#  [ 2.76011225 12.25368975  9.02035225 16.72371431 25.40987895 38.56077323]
#  [13.46842787 14.26668903  9.22621112 16.11109105 32.40732467 46.47646658]
#  [ 9.44183424 14.49338816  9.969118   16.37206673 26.05891067 42.59094623]
#  [ 7.234898   14.32809412 10.03236133 16.69296094 25.24526547 58.3874068 ]
#  [ 1.37364328 11.58257431 10.04973871 17.13433532 32.68230582 59.99269061]
#  [ 8.32580677  7.53015535  9.837008   16.92562965 28.00709113 62.0138222 ]
#  [ 7.16967172 10.47243272  9.9258498  16.84253727 32.78101812 38.05344156]
#  [20.98035587 10.44069114  9.72703287 16.91680912 26.56305981 54.079984  ]
#  [19.76371781  9.15166429  9.57133098 16.90079192 32.59638058 48.64724475]
#  [18.81811227  7.34097238  9.55421298 17.09880306 34.51598528 48.63014166]
#  [26.6391075  12.23594728  9.43081925 16.93223746 31.56190825 54.11960555]
#  [ 3.87661572  9.27905237  9.80185197 16.36745782 29.36401982 45.81705056]
#  [29.66950489 13.00821514  9.94128001 16.41022166 25.42672919 64.28633568]
#  [13.15169113 13.05624151  9.97145134 16.14407505 30.00765701 64.86310384]
#  [21.43858606  6.65445116  9.12845    16.65910482 30.64193647 54.90424149]
#  [28.16522863 13.49290723  9.18860119 16.7162246  30.64581287 60.61852722]
#  [16.85312266 10.50007389  9.31432464 16.92756357 34.52245274 64.89380829]
#  [ 5.87866948 14.48375182  9.30008386 16.37680579 28.87804518 36.59536808]
#  [ 9.280261   12.08614061 10.06990763 16.76888048 25.01538534 61.1473112 ]
#  [ 5.99716922 10.15772157  9.18604752 16.54914846 29.46144448 43.28505514]
#  [ 1.80176355  8.08721924  9.96819363 16.4305285  33.19324003 41.19428506]
#  [ 6.16949697 12.87629623 10.16964711 17.08207192 26.67708931 61.99910522]
#  [24.78145381 12.61999656  9.51499262 16.50168562 27.73985815 54.65072652]
#  [17.62592106 11.98375222  9.68881272 16.21181888 28.43365321 62.31499741]
#  [27.09430846 10.38845335  9.43022831 16.67933722 25.86504178 40.46562253]]

# %%
# mostramos las barras
fig,ax = plt.subplots(1,3,figsize=(8,2))

# barra simples
ax[0].bar(range(n),np.mean(data,axis=0))
ax[0].set_title('Bar Plot')

# barras de errores
ax[1].errorbar(range(n),np.mean(data,axis=0),np.std(data,axis=0,ddof=1),marker='s',linestyle='')
ax[1].set_title('Errorbar plot')

# ambos
ax[2].bar(range(n),np.mean(data,axis=0))
ax[2].errorbar(range(n),np.mean(data,axis=0),np.std(data,axis=0,ddof=1),marker='.',linestyle='',color='k')
ax[2].set_title('Error+bar Plot')

plt.show()

# %%
# Especificando el eje x manualmente
xcrossings = [1,2,4,5,6,9]
plt.bar(xcrossings,np.mean(data,axis=0))
plt.errorbar(xcrossings, np.mean(data,axis=0),np.std(data,axis=0,ddof=1),marker='.',linestyle='',color='k')
plt.title('Bar+error plot')

plt.show()

# %%
## note about bars from matrices

# Datos agrupados en (filas) con la propiedad (columnas)
m = [ [2,5,4,3], [1,1,8,6] ]

fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(8,8))

# conceptualizando los datos como <filas> agrupados en <columnas>
ax[0,0].imshow(m)

# usando panda dataframe
df = pd.DataFrame(m,columns=['prop 0','prop 1','prop 2','prop 3'])
df.plot(ax=ax[1,0],kind='bar')
ax[1,0].set_title('Agrupando por filas')


# ahora otra orientacion (property X group)
ax[0,1].imshow(np.array(m).T)
df.T.plot(ax=ax[1,1],kind='bar')
ax[1,1].set_title('Agrupando por columnas')

plt.show()
